# %%
import sys
import json
from pathlib import Path

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

from evaluation.deviations_evalaution_metrics import DeviationEvaluation

# %% [markdown]
# # Evaluation deviation labels

# %%
path_pred_deviations = "../../../../results/Sepsis/predictions/deviation_predictions.json"

with Path(path_pred_deviations).open("r") as f:
    items = json.load(f)
deviation_results_evaluation = items

eval = DeviationEvaluation(deviation_results=deviation_results_evaluation)

# %%
# Only evaluate labels that are in the target set!
precision_macro, recall_macro, precision_per_label, recall_per_label = eval.precision_recall_macro_by_label_dev()
print("Precision macro dev: ", precision_macro)
print("Precision macro dev per label: ", precision_per_label)
print("Recall macro dev: ", recall_macro)
print("Recall macro dev per label: ", recall_per_label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Only evaluate labels that are in the target set!
# ----> 2 precision_macro, recall_macro, precision_per_label, recall_per_label = eval.precision_recall_macro_by_label_dev()
#       3 print("Precision macro dev: ", precision_macro)
#       4 print("Precision macro dev per label: ", precision_per_label)
#
# File ~/ProbabilisticSuffixPredictionLab/risk_controlled_proactive_conformance_checking_dev/src/notebooks/evaluation/Sepsis/../../../evaluation/deviations_evalaution_metrics.py:120, in DeviationEvaluation.precision_recall_macro_by_label_dev(self)
#     118 # accumulate counts per-case (TP computed as min per case)
#     119 for tgt_list, pred_list in zip(tgt_deviations, pred_deviations):
# --> 120     p_ctr = Counter(pred_list)
#     121     t_ctr = Counter(tgt_list)
#     122     labels_union = set(p_ctr) | set(t_ctr)
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/collections/__init__.py:611, in Counter.__init__(self, iterable, **kwds)
#     600 '''Create a new, empty Counter object.  And if given, count elements
#     601 from an input iterable.  Or, initialize the count from another mapping
#     602 of elements to their counts.
#    (...)
#     608
#     609 '''
#     610 super().__init__()
# --> 611 self.update(iterable, **kwds)
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/collections/__init__.py:703, in Counter.update(self, iterable, **kwds)
#     701             super().update(iterable)
#     702     else:
# --> 703         _count_elements(self, iterable)
#     704 if kwds:
#     705     self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %%
precision_macro, recall_macro, precision_per_label, recall_per_label = eval.precision_recall_macro_by_label_no_dev()
print("Precision macro no dev: ", precision_macro)
print("Precision macro per label no dev: ", precision_per_label)
print("Recall macro no dev: ", recall_macro)
print("Recall macro per label no dev: ", recall_per_label)

# %%
roc_auc_macro, roc_auc_per_label = eval.roc_auc_macro_by_label()
print("ROC_AUC macro dev: ", roc_auc_macro)
print("ROC_AUC macro dev per label: ", roc_auc_per_label)
