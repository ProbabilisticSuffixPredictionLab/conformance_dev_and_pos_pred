# %%
import os
import sys
import pickle

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

from load_data.load_conformal_data import load_suffix_results
from conformance_checking.conformance import ConformanceChecking
from conformance_checking.conformance_results import ConformanceResults

# %%
# Load model and suffix test set and determine output directory:

# Helpdesk
# log_name = "Helpdesk"
# path_to_be_model = "../../../data/process_models/Helpdesk.bpmn"
# path_test_samples_results = "../../../../../data/Helpdesk/proact_conf_check/eval_test_set/"
# output_dir   = "../../../../../data/Helpdesk/proact_conf_check/online_prediction/"

# Sepsis:
# log_name = "Sepsis"
# path_to_be_model = "../../../data/process_models/Sepsis.bpmn"
# path_test_samples_results = "../../../../../data/Sepsis/proact_conf_check/eval_test_set/"
# output_dir   = "../../../../../data/Sepsis/proact_conf_check/online_prediction/"

# BPIC20:
log_name = "BPIC20-DD"
path_to_be_model = "../../../data/process_models/BPIC-20-DomesticDeclarations.bpmn"
path_test_samples_results = "../../../../../data/BPIC20/proact_conf_check/eval_test_set/"
output_dir   = "../../../../../data/BPIC20/proact_conf_check/online_prediction/"

# %%
# MC Suffix Sampling Results
results = load_suffix_results(path=path_test_samples_results)

# Conformance Checking object:
cc = ConformanceChecking(path_process_model=path_to_be_model)

# Evaluate the probabilistic suffix samples using conformance checking:
cfr = ConformanceResults(log_name=log_name, data=results, conformance_object=cc)
test_conformance_dict = cfr.conformance_results(target_workers=128)
print("Finished conformance checking computation")

os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists

# Batch size to store multiple tuples
n = 50

num_cases = len(test_conformance_dict['case_id'])
total_saved = 0
for i in range(0, num_cases, n):
    batch = {k: v[i:i+n] for k, v in test_conformance_dict.items()}
    
    chunk_number = (i//n+1) * n
    filename = os.path.join(output_dir, f'conformance_res_{chunk_number:03d}.pkl')
    
    with open(filename, 'wb') as f:
        pickle.dump(batch, f)
    batch_size = len(batch['case_id'])
    total_saved += batch_size
    print(f"Saved {batch_size} entries to {filename}")

print(f"Saved a total of {total_saved} entries across { (num_cases + n - 1) // n } files")
print("All files stored!")
# Out:
# Looking for .pkl files in: ../../../../../data/BPIC20/proact_conf_check/eval_test_set/
# Resolved absolute path: /home/PSPLab/data/BPIC20/proact_conf_check/eval_test_set
# Found 138 files
# Loaded all suffix results!
# Finished conformance checking computation
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_1950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_2950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_3950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_4950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_5950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6800.pkl
# Saved 45 entries to ../../../../../data/BPIC20/proact_conf_check/online_prediction/conformance_res_6850.pkl
# Saved a total of 6845 entries across 137 files
# All files stored!
