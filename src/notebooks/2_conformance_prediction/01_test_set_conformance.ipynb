# %%
import os
import sys
import pickle

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

from load_data.load_conformal_data import load_suffix_results
from conformance_checking.conformance import ConformanceChecking
from conformance_checking.conformance_results import ConformanceResults

# %%
# Load model and validation set and determine output directory:

# Helpdesk
log_name = "Helpdesk"
path_to_be_model = "../../../data/process_models/Helpdesk.bpmn"
path_test_samples_results = "../../../../../data/Helpdesk/proact_conf_check/eval_test_set/"
output_dir   = "../../../../../data/Helpdesk/proact_conf_check/online_prediction/"

# Sepsis:
# log_name = "Sepsis"
# path_to_be_model = "../../../data/process_models/Sepsis.bpmn"
# path_calibration_samples_results = "../../../../../data/Sepsis/proact_conf_check/eval_test_set/"
# output_dir   = "../../../../../data/Sepsis/proact_conf_check/online_prediction/"

# %%
# Compute the fitness scores for all probabilistic suffix samples for all cases in the validation dataset:

# MC Suffix Sampling Results
results = load_suffix_results(path=path_test_samples_results)

# Conformance Checking object:
cc = ConformanceChecking(path_process_model=path_to_be_model)

# Evaluate the probabilistic suffix samples using conformance checking:
cfr = ConformanceResults(log_name=log_name, data=results, conformance_object=cc)
test_conformance_dict = cfr.conformance_results(target_workers=64)
print("Finished conformance checking computation")

# Testing purpose
# test = cfr.quick_fitness()

os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists

# Batch size to store multiple tuples
n = 50

num_cases = len(test_conformance_dict['case_id'])
total_saved = 0
for i in range(0, num_cases, n):
    batch = {k: v[i:i+n] for k, v in test_conformance_dict.items()}
    
    chunk_number = (i//n+1) * n
    filename = os.path.join(output_dir, f'conformance_res_{chunk_number:03d}.pkl')
    
    with open(filename, 'wb') as f:
        pickle.dump(batch, f)
    batch_size = len(batch['case_id'])
    total_saved += batch_size
    print(f"Saved {batch_size} entries to {filename}")

print(f"Saved a total of {total_saved} entries across { (num_cases + n - 1) // n } files")
print("All files stored!")
# Out:
# Looking for .pkl files in: ../../../../../data/Helpdesk/proact_conf_check/eval_test_set/
# Resolved absolute path: /home/PSPLab/data/Helpdesk/proact_conf_check/eval_test_set
# Found 51 files
# Loaded all suffix results!
# Finished conformance checking computation
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_050.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_100.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_150.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_200.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_250.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_300.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_350.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_400.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_450.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_500.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_550.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_600.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_650.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_700.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_750.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_800.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_850.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_900.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_950.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1000.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1050.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1100.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1150.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1200.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1250.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1300.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1350.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1400.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1450.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1500.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1550.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1600.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1650.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1700.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1750.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1800.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1850.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1900.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_1950.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2000.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2050.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2100.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2150.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2200.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2250.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2300.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2350.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2400.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2450.pkl
# Saved 50 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2500.pkl
# Saved 44 entries to ../../../../../data/Helpdesk/proact_conf_check/online_prediction/conformance_res_2550.pkl
# Saved a total of 2544 entries across 51 files
# All files stored!
