# %%
import os
import sys
import pickle

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

from load_data.load_conformal_data import load_suffix_results
from conformance_checking.conformance import ConformanceChecking
from conformance_checking.conformance_results import ConformanceResults

# %%
# Load model and suffix validation set and determine output directory:

# Helpdesk
# log_name = "Helpdesk"
# path_to_be_model = "../../../data/process_models/Helpdesk.bpmn"
# path_calibration_samples_results = "../../../../../data/Helpdesk/proact_conf_check/eval_validation_set/"
# output_dir   = "../../../../../data/Helpdesk/proact_conf_check/offline_analysis/"

# Sepsis:
# log_name = "Sepsis"
# path_to_be_model = "../../../data/process_models/Sepsis.bpmn"
# path_calibration_samples_results = "../../../../../data/Sepsis/proact_conf_check/eval_validation_set/"
# output_dir   = "../../../../../data/Sepsis/proact_conf_check/offline_analysis/"

# BPIC20:
log_name = "BPIC20-DD"
path_to_be_model = "../../../data/process_models/BPIC-20-DomesticDeclarations.bpmn"
path_calibration_samples_results = "../../../../../data/BPIC20/proact_conf_check/eval_validation_set/"
output_dir   = "../../../../../data/BPIC20/proact_conf_check/offline_analysis/"

# %%
# MC Suffix Sampling Results
results = load_suffix_results(path=path_calibration_samples_results)

# Conformance Checking object:
cc = ConformanceChecking(path_process_model=path_to_be_model)

# Evaluate the probabilistic suffix samples using conformance checking:
cfr = ConformanceResults(log_name=log_name, data=results, conformance_object=cc)
calibration_conformance_dict = cfr.conformance_results(target_workers=128)
print("Finished conformance checking computation")

# Testing purpose
# test = cfr.quick_fitness()

os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists

# Batch size to store multiple tuples
n = 50

num_cases = len(calibration_conformance_dict['case_id'])
total_saved = 0
for i in range(0, num_cases, n):
    batch = {k: v[i:i+n] for k, v in calibration_conformance_dict.items()}
    
    chunk_number = (i//n+1) * n
    filename = os.path.join(output_dir, f'conformance_res_{chunk_number:03d}.pkl')
    
    with open(filename, 'wb') as f:
        pickle.dump(batch, f)
    batch_size = len(batch['case_id'])
    total_saved += batch_size
    print(f"Saved {batch_size} entries to {filename}")

print(f"Saved a total of {total_saved} entries across { (num_cases + n - 1) // n } files")
print("All files stored!")
# Out:
# Looking for .pkl files in: ../../../../../data/BPIC20/proact_conf_check/eval_validation_set/
# Resolved absolute path: /home/PSPLab/data/BPIC20/proact_conf_check/eval_validation_set
# Found 276 files
# Loaded all suffix results!
# Finished conformance checking computation
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_1950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_2950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_3950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_4950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_5950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_6950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_7950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_8950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_9950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_10950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_11950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12750.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12800.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12850.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12900.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_12950.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13000.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13050.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13100.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13150.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13200.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13250.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13300.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13350.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13400.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13450.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13500.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13550.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13600.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13650.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13700.pkl
# Saved 50 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13750.pkl
# Saved 24 entries to ../../../../../data/BPIC20/proact_conf_check/offline_analysis/conformance_res_13800.pkl
# Saved a total of 13774 entries across 276 files
# All files stored!
